# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")    
os.environ["lanchain_project"] = os.getenv("lanchain_project")  
print(os.getenv("OPENAI_API_KEY"))
print(os.getenv("LANGCHAIN_API_KEY"))
# Out:
# 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
# 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

# %%
from langchain_community.embeddings import OllamaEmbeddings
embeddings=(OllamaEmbeddings(model="llama3"))
r1=embeddings.embed_documents(
    [
        "Alpha is the first letter of the Greek alphabet.",
        "Beta is the second letter of the Greek alphabet."
    ]
)
r1[0]
len(r1[0])
# Out:
# 4096
